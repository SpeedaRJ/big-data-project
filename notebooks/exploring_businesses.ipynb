# %%
import pandas as pd
import numpy as np

# %%
businesses = pd.read_csv('../data/additional_data/businesses/businesses_NYC_2023_processed.csv')

# %%
businesses["License Expiration Date"] = pd.to_datetime(businesses["License Expiration Date"]).astype(np.int64) // 10**6
businesses["License Creation Date"] = pd.to_datetime(businesses["License Creation Date"]).astype(np.int64) // 10**6

# %%
data_time_range = (
    pd.Timestamp(year=2013, month=7, day=1, unit="ms"),
    pd.Timestamp(year=2024, month=6, day=30, unit="ms"),
)

# %%
businesses
# Out:
#         License Expiration Date  License Creation Date  \
# 0                 1112227200000           860457600000
# 1                 1104451200000           986169600000
# 2                 1640908800000          1511568000000
# 3                 1590192000000          1402272000000
# 4                 1627689600000          1465430400000
# ...                         ...                    ...
# 172327            1609372800000          1375142400000
# 172328            1753920000000          1193011200000
# 172329            1735603200000          1689120000000
# 172330            1753920000000          1055289600000
# 172331            1703980800000          1460419200000
#
#                            Industry                          Business Name  \
# 0                            Garage   THE GARDENS 75TH STREET OWNERS CORP.
# 1             Tobacco Retail Dealer                  JALIL, MOHAMMED ABDUL
# 2                         Laundries               SING WAH LAUNDROMAT INC.
# 3                     Sidewalk Cafe               DCB DELANCEY CORPORATION
# 4       Secondhand Dealer - General            MD BROADWAY ELECTRONICS LLC
# ...                             ...                                    ...
# 172327        Tobacco Retail Dealer                      JUNCTION MART INC
# 172328  Secondhand Dealer - General                        DASAM SONS INC.
# 172329            Electronics Store           GALAXY LATINO GIFT SHOP CORP
# 172330  Secondhand Dealer - General  1672 62ND STREET R & J COLLISION INC.
# 172331        Tobacco Retail Dealer                COLUMBIA SMOKE SHOP INC
#
#         Longitude   Latitude
# 0      -73.891136  40.750745
# 1      -73.960737  40.650123
# 2      -74.023621  40.634397
# 3      -73.993820  40.720242
# 4      -73.906078  40.855206
# ...           ...        ...
# 172327 -73.869095  40.748608
# 172328 -73.979629  40.776247
# 172329 -74.005189  40.650050
# 172330 -73.991506  40.622725
# 172331 -73.964838  40.801648
#
# [172332 rows x 6 columns]

# %%
businesses = businesses[businesses["License Expiration Date"] > businesses["License Creation Date"]]

# %%
middle_schools = pd.read_csv('../data/additional_data/schools/middle_schools_NYC_2021_processed.csv')

# %%
from haversine import haversine
from rtree.index import Index

# %%
def create_rtree_index(df, name):
    idx = Index()
    for i, row in enumerate(df.iterrows()):
        row = row[1]
        idx.insert(
            i,
            (row["Latitude"], row["Longitude"], row["Latitude"], row["Longitude"]),
            obj={"name": row[name], "industry": row["Industry"],"lat": row["Latitude"], "long": row["Longitude"], "active_from": row["License Creation Date"], "active_to": row["License Expiration Date"]},
        )
    return idx


businesses_idx = create_rtree_index(businesses, "Business Name")

# %%
issue_time = 1372723200000

# %%
def get_nearest_locations(idx, lat, lang, n):
    return [item.object for item in list(idx.nearest((lat, lang, lat, lang), n, objects=True))]

def computational_wrapper(row, lat_i, long_i, idx, time_i, n=16):
    locations = pd.DataFrame(get_nearest_locations(idx, row[lat_i], row[long_i], n))
    locations = locations[(locations["active_from"] <= row[time_i]) & (locations["active_to"] >= row[time_i])]
    if locations.empty:
        return computational_wrapper(row, lat_i, long_i, idx, time_i, n * 2)
    return (locations.iloc[0]["name"], locations.iloc[0]["industry"], haversine((row[lat_i], row[long_i]), (locations.iloc[0]["lat"], locations.iloc[0]["long"])))

# %%
middle_schools = middle_schools.assign(time=issue_time)

# %%
middle_schools
# Out:
#                                               name   Latitude  Longitude  \
# 0                   P.S. 034 Franklin D. Roosevelt  40.726473 -73.975181
# 1                           P.S. 140 Nathan Straus  40.719250 -73.983056
# 2                             P.S. 184m Shuang Wen  40.711549 -73.986542
# 3                       P.S. 188 The Island School  40.719598 -73.977904
# 4            University Neighborhood Middle School  40.713684 -73.986336
# ..                                             ...        ...        ...
# 467                  I.S. 347 School of Humanities  40.700690 -73.927481
# 468                 I.S. 349 Math, Science & Tech.  40.700690 -73.927481
# 469                   J.H.S. 383 Philippa Schuyler  40.697781 -73.919777
# 470               P.S. /I.S. 384 Frances E. Carter  40.690353 -73.904803
# 471  Evergreen Middle School for Urban Exploration  40.688387 -73.910276
#
#               time
# 0    1372723200000
# 1    1372723200000
# 2    1372723200000
# 3    1372723200000
# 4    1372723200000
# ..             ...
# 467  1372723200000
# 468  1372723200000
# 469  1372723200000
# 470  1372723200000
# 471  1372723200000
#
# [472 rows x 4 columns]

# %%
lat_i = middle_schools.columns.tolist().index("Latitude") + 1
long_i = middle_schools.columns.tolist().index("Longitude") + 1
time_i = middle_schools.columns.tolist().index("time") + 1

# %%
res = []

for row in middle_schools.itertuples():
    res.append(computational_wrapper(row, lat_i, long_i, businesses_idx, time_i))

# %%
res = pd.DataFrame(
        res,
        columns=["Closest Business", "Industry of Business", "Distance to Business"],
        index=middle_schools.index,
    )

# %%
res
# Out:
#                          Closest Business         Industry of Business  \
# 0    D' MARGARITA DELI GROCERY CORP.CORP.        Tobacco Retail Dealer
# 1          MASTER MINIMARKET & DELI CORP.        Tobacco Retail Dealer
# 2        ASIAN AMERICAN CONSTRUCTION INC.  Home Improvement Contractor
# 3                         23 AVE. D CORP.        Tobacco Retail Dealer
# 4                  LAUNDRY QUEEN III INC.                      Laundry
# ..                                    ...                          ...
# 467             BROTHER'S DRY CLEANER CRP               Laundry Jobber
# 468             BROTHER'S DRY CLEANER CRP               Laundry Jobber
# 469         RAYDAN DELI & GROCERY 1, INC.        Tobacco Retail Dealer
# 470    DORESANTIAGO HOME IMPROVEMENT INC.  Home Improvement Contractor
# 471                        TORRES, EMILIO                      Laundry
#
#      Distance to Business
# 0                0.191874
# 1                0.017933
# 2                0.171376
# 3                0.130344
# 4                0.063496
# ..                    ...
# 467              0.093860
# 468              0.093860
# 469              0.085890
# 470              0.027451
# 471              0.064142
#
# [472 rows x 3 columns]

# %%
middle_schools.merge(res, left_index=True, right_index=True)
# Out:
#                                               name   Latitude  Longitude  \
# 0                   P.S. 034 Franklin D. Roosevelt  40.726473 -73.975181
# 1                           P.S. 140 Nathan Straus  40.719250 -73.983056
# 2                             P.S. 184m Shuang Wen  40.711549 -73.986542
# 3                       P.S. 188 The Island School  40.719598 -73.977904
# 4            University Neighborhood Middle School  40.713684 -73.986336
# ..                                             ...        ...        ...
# 467                  I.S. 347 School of Humanities  40.700690 -73.927481
# 468                 I.S. 349 Math, Science & Tech.  40.700690 -73.927481
# 469                   J.H.S. 383 Philippa Schuyler  40.697781 -73.919777
# 470               P.S. /I.S. 384 Frances E. Carter  40.690353 -73.904803
# 471  Evergreen Middle School for Urban Exploration  40.688387 -73.910276
#
#               time                      Closest Business  \
# 0    1372723200000  D' MARGARITA DELI GROCERY CORP.CORP.
# 1    1372723200000        MASTER MINIMARKET & DELI CORP.
# 2    1372723200000      ASIAN AMERICAN CONSTRUCTION INC.
# 3    1372723200000                       23 AVE. D CORP.
# 4    1372723200000                LAUNDRY QUEEN III INC.
# ..             ...                                   ...
# 467  1372723200000             BROTHER'S DRY CLEANER CRP
# 468  1372723200000             BROTHER'S DRY CLEANER CRP
# 469  1372723200000         RAYDAN DELI & GROCERY 1, INC.
# 470  1372723200000    DORESANTIAGO HOME IMPROVEMENT INC.
# 471  1372723200000                        TORRES, EMILIO
#
#             Industry of Business  Distance to Business
# 0          Tobacco Retail Dealer              0.191874
# 1          Tobacco Retail Dealer              0.017933
# 2    Home Improvement Contractor              0.171376
# 3          Tobacco Retail Dealer              0.130344
# 4                        Laundry              0.063496
# ..                           ...                   ...
# 467               Laundry Jobber              0.093860
# 468               Laundry Jobber              0.093860
# 469        Tobacco Retail Dealer              0.085890
# 470  Home Improvement Contractor              0.027451
# 471                      Laundry              0.064142
#
# [472 rows x 7 columns]

# %%
import dask.dataframe as dd

tickets = dd.read_parquet('../data/parking_tickets/parquet/full_data_cleaned.parquet')

tmp = tickets.head()

res = []

lat_i = tmp.columns.tolist().index("Latitude") + 1
long_i = tmp.columns.tolist().index("Longitude") + 1
time_i = tmp.columns.tolist().index("Issue Date") + 1

for row in tmp.itertuples():
    res.append(computational_wrapper(row, lat_i, long_i, businesses_idx, time_i))


res = pd.DataFrame(
    res,
    columns=["bussiness", "industry", "distance"],
    index=tmp.index,
)

tmp.merge(res, left_index=True, right_index=True)
# Out:
#       Summons Number  Plate ID Registration State Plate Type     Issue Date  \
# 7285      1351801788   41666JM                 NY        COM  1372723200000
# 7443      1351801790   99208MC                 NY        COM  1372723200000
# 7733      1351801806   49965JG                 NY        COM  1372723200000
# 8322      1291521665  YANKYJAM                 NY        PAS  1372723200000
# 8325      1335816963    XX865Y                 NJ        PAS  1372723200000
#
#       Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 7285              14               VAN                           P
# 7443              14               VAN                           P
# 7733              14               VAN                           P
# 8322              46               SDN          BMW              F
# 8325              78              DELV        CHEVR              P
#
#       Street Code1  ...  Vehicle Color  Vehicle Year  Feet From Curb  \
# 7285         45440  ...                            0               0
# 7443         45440  ...                            0               0
# 7733         13590  ...                            0               0
# 8322          5430  ...            BLK             0               0
# 8325         24790  ...          WHITE             0               0
#
#       Violation Post Code  Violation Description   Latitude  Longitude  \
# 7285                                              40.707333 -74.007828
# 7443                                              40.707333 -74.007828
# 7733                                              40.703620 -74.010706
# 8322                                              40.645503 -74.013282
# 8325                                              40.719650 -74.010185
#
#                                 bussiness               industry  distance
# 7285  AHRC NEW YORK CITY FOUNDATION, INC.        Games of Chance  0.022238
# 7443  AHRC NEW YORK CITY FOUNDATION, INC.        Games of Chance  0.022238
# 7733        PEARLSTONE BURGER CORPORATION          Sidewalk Cafe  0.050663
# 8322   S.N.A. FINEST DELI & GROCERY CORP.  Tobacco Retail Dealer  0.027400
# 8325            TRIBECA DELICATESSEN INC.  Tobacco Retail Dealer  0.007857
#
# [5 rows x 42 columns]
