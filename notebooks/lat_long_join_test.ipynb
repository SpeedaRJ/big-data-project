# %%
import dask.dataframe as dd
from haversine import haversine

high_schools = dd.read_csv("../data/additional_data/schools/high_schools_NYC_2021_processed.csv")
middle_schools = dd.read_csv("../data/additional_data/schools/middle_schools_NYC_2021_processed.csv").compute()

# %%
high_schools = high_schools.repartition(npartitions=1)

# %%
import numpy as np
import dask

test = None

results = []

for index, row in high_schools.iterrows():
    tmp = row.to_frame().T.assign(key=0).set_index("key")
    tmp = tmp.merge(middle_schools.assign(key=0).set_index("key"), how="inner", left_index=True, right_index=True)
    tmp = tmp.assign(distance=tmp.apply(lambda row: haversine((row['Latitude_x'], row['Longitude_x']), (row['Latitude_y'], row['Longitude_y'])), axis=1))
    tmp = tmp.sort_values("distance").groupby(['school_name']).first().reset_index()
    results.append((tmp["name"].values[0], tmp["distance"].values[0]))

results = np.array(results)

high_schools = high_schools.assign(Closest_Middle_School=dask.array.from_array(results[:, 0]))
high_schools = high_schools.assign(Distance_to_CMS=dask.array.from_array(results[:, 1]))
high_schools = high_schools.reset_index()

# %%
high_schools.compute()
# Out:
#      index                                        school_name   Latitude  \
# 0        0                         Orchard Collegiate Academy  40.713684
# 1        1                University Neighborhood High School  40.712399
# 2        2                         East Side Community School  40.729589
# 3        3                          Forsyth Satellite Academy  40.722520
# 4        4  New Explorations into Science, Technology and ...  40.718895
# ..     ...                                                ...        ...
# 437    437      EBC High School for Public Service - Bushwick  40.694507
# 438    438            Brooklyn School for Social Justice, The  40.697185
# 439    439     Academy of Urban Planning and Engineering, The  40.697185
# 440    440               All City Leadership Secondary School  40.697370
# 441    441  Bushwick Leaders High School for Academic Exce...  40.695056
#
#      Longitude                             Closest_Middle_School  \
# 0   -73.986336             University Neighborhood Middle School
# 1   -73.984497                              P.S. 184m Shuang Wen
# 2   -73.982555                        East Side Community School
# 3   -73.990728                         School for Global Leaders
# 4   -73.979308  New Explorations into Science, Technology & Math
# ..         ...                                               ...
# 437 -73.929107                         Madiba Prep Middle School
# 438 -73.911170              All City Leadership Secondary School
# 439 -73.911170              All City Leadership Secondary School
# 440 -73.913171              All City Leadership Secondary School
# 441 -73.928140                         Madiba Prep Middle School
#
#          Distance_to_CMS
# 0                    0.0
# 1    0.19657732222615024
# 2                    0.0
# 3    0.47956312756173775
# 4                    0.0
# ..                   ...
# 437  0.34501750725612484
# 438  0.16994244445222528
# 439  0.16994244445222528
# 440                  0.0
# 441   0.4447541452618034
#
# [442 rows x 6 columns]

# %%
merged = dd.map_partitions(
    lambda df: df.assign(key=0).set_index("key").merge(middle_schools.assign(key=0).set_index("key"), how="left", left_index=True, right_index=True),
    high_schools,
)

merged = merged.map_partitions(
    lambda df: df.assign(distance=df.apply(lambda row: haversine((row['Latitude_x'], row['Longitude_x']), (row['Latitude_y'], row['Longitude_y'])), axis=1))
)

merged = merged.map_partitions(
    lambda df: df.sort_values("distance").groupby(['school_name']).first()
)

merged.compute()
# Out:
#                                                     Latitude_x  Longitude_x  \
# school_name
# Orchard Collegiate Academy                           40.713684   -73.986336
# University Neighborhood High School                  40.712399   -73.984497
# East Side Community School                           40.729589   -73.982555
# Forsyth Satellite Academy                            40.722520   -73.990728
# New Explorations into Science, Technology and M...   40.718895   -73.979308
# ...                                                        ...          ...
# EBC High School for Public Service - Bushwick        40.694507   -73.929107
# Brooklyn School for Social Justice, The              40.697185   -73.911170
# Academy of Urban Planning and Engineering, The       40.697185   -73.911170
# All City Leadership Secondary School                 40.697370   -73.913171
# Bushwick Leaders High School for Academic Excel...   40.695056   -73.928140
#
#                                                                                                 name  \
# school_name
# Orchard Collegiate Academy                                     University Neighborhood Middle School
# University Neighborhood High School                                             P.S. 184m Shuang Wen
# East Side Community School                                                East Side Community School
# Forsyth Satellite Academy                                                  School for Global Leaders
# New Explorations into Science, Technology and M...  New Explorations into Science, Technology & Math
# ...                                                                                              ...
# EBC High School for Public Service - Bushwick                              Madiba Prep Middle School
# Brooklyn School for Social Justice, The                         All City Leadership Secondary School
# Academy of Urban Planning and Engineering, The                  All City Leadership Secondary School
# All City Leadership Secondary School                            All City Leadership Secondary School
# Bushwick Leaders High School for Academic Excel...                         Madiba Prep Middle School
#
#                                                     Latitude_y  Longitude_y  \
# school_name
# Orchard Collegiate Academy                           40.713684   -73.986336
# University Neighborhood High School                  40.711549   -73.986542
# East Side Community School                           40.729589   -73.982555
# Forsyth Satellite Academy                            40.720581   -73.985645
# New Explorations into Science, Technology and M...   40.718895   -73.979308
# ...                                                        ...          ...
# EBC High School for Public Service - Bushwick        40.692126   -73.931731
# Brooklyn School for Social Justice, The              40.697370   -73.913171
# Academy of Urban Planning and Engineering, The       40.697370   -73.913171
# All City Leadership Secondary School                 40.697370   -73.913171
# Bushwick Leaders High School for Academic Excel...   40.692126   -73.931731
#
#                                                     distance
# school_name
# Orchard Collegiate Academy                          0.000000
# University Neighborhood High School                 0.196577
# East Side Community School                          0.000000
# Forsyth Satellite Academy                           0.479563
# New Explorations into Science, Technology and M...  0.000000
# ...                                                      ...
# EBC High School for Public Service - Bushwick       0.345018
# Brooklyn School for Social Justice, The             0.169942
# Academy of Urban Planning and Engineering, The      0.169942
# All City Leadership Secondary School                0.000000
# Bushwick Leaders High School for Academic Excel...  0.444754
#
# [442 rows x 6 columns]

# %%
from dask.distributed import Client, LocalCluster

cluster = LocalCluster(n_workers=1, threads_per_worker=16, memory_target_fraction=0.95, memory_limit='64GB')
client = Client(cluster)

tickets = dd.read_parquet("../data/parking_tickets/parquet/full_data_cleaned.parquet").repartition(npartitions=1)

# %%
from tqdm.notebook import tqdm
import numpy as np
import dask

test = None

results = []

for index, row in tqdm(tickets.iterrows()):
    tmp = row.to_frame().T.assign(key=0).set_index("key")
    tmp = tmp.merge(middle_schools.assign(key=0).set_index("key"), how="inner", left_index=True, right_index=True)
    tmp = tmp.assign(distance=tmp.apply(lambda row: haversine((row['Latitude_x'], row['Longitude_x']), (row['Latitude_y'], row['Longitude_y'])), axis=1))
    tmp = tmp.sort_values("distance").groupby(['school_name']).first().reset_index()
    results.append((tmp["name"].values[0], tmp["distance"].values[0]))

results = np.array(results)

tickets = tickets.assign(Closest_Middle_School=dask.array.from_array(results[:, 0]))
tickets = tickets.assign(Distance_to_CMS=dask.array.from_array(results[:, 1]))
tickets = tickets.reset_index()
# Out:
# 0it [00:00, ?it/s]

# %%
tickets.compute()

# %%
merged = dd.map_partitions(
    lambda df: df.assign(key=0).set_index("key").merge(middle_schools.assign(key=0).set_index("key"), how="left", left_index=True, right_index=True),
    tickets,
)

# %%
merged = merged.map_partitions(
    lambda df: df.assign(distance=df.apply(lambda row: haversine((row['Latitude_x'], row['Longitude_x']), (row['Latitude_y'], row['Longitude_y'])), axis=1))
)

# %%
merged = merged.map_partitions(
    lambda df: df.sort_values("distance").groupby(['Summons Number']).first()
)
